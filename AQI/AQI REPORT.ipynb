# %% [markdown]
# # AQI Analysis

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#importing Dataset firstly from device using pandas
data=pd.read_csv("AQI.csv")
data
# Out:
#                         Country              City  AQI Value AQI Category
# 0            Russian Federation        Praskoveya         51     Moderate  \
# 1                        Brazil  Presidente Dutra         41         Good
# 2                        Brazil  Presidente Dutra         41         Good
# 3                         Italy   Priolo Gargallo         66     Moderate
# 4                        Poland         Przasnysz         34         Good
# ...                         ...               ...        ...          ...
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16693                    France            Sceaux         50         Good
# 16694  United States of America       Westerville         71     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category
# ...

# %% [markdown]
# ## Cleaning Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16393 non-null  object
#  1   City                16695 non-null  object
#  2   AQI Value           16695 non-null  int64
#  3   AQI Category        16695 non-null  object
#  4   CO AQI Value        16695 non-null  int64
#  5   CO AQI Category     16695 non-null  object
#  6   Ozone AQI Value     16695 non-null  int64
#  7   Ozone AQI Category  16695 non-null  object
#  8   NO2 AQI Value       16695 non-null  int64
#  9   NO2 AQI Category    16695 non-null  object
#  10  PM2.5 AQI Value     16695 non-null  int64
#  11  PM2.5 AQI Category  16695 non-null  object
#  12  lat                 16695 non-null  float64
#  13  lng                 16695 non-null  float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.8+ MB

# %%
data.shape
# Out:
# (16695, 14)

# %%
data.isnull()
# Out:
#        Country   City  AQI Value  AQI Category  CO AQI Value  CO AQI Category
# 0        False  False      False         False         False            False  \
# 1        False  False      False         False         False            False
# 2        False  False      False         False         False            False
# 3        False  False      False         False         False            False
# 4        False  False      False         False         False            False
# ...        ...    ...        ...           ...           ...              ...
# 16690    False  False      False         False         False            False
# 16691    False  False      False         False         False            False
# 16692    False  False      False         False         False            False
# 16693    False  False      False         False         False            False
# 16694    False  False      False         False         False            False
#
# ...

# %%
data.isnull().sum()
# Out:
# Country               302
# City                    0
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# lat                     0
# lng                     0
# dtype: int64

# %% [markdown]
# ## Now Droping Unwanted or Not Filled Data From Dataset

# %%
data.dropna(axis=1,inplace=True)

# %%
data.head(10)
# Out:
#                City  AQI Value AQI Category  CO AQI Value CO AQI Category
# 0        Praskoveya         51     Moderate             1            Good  \
# 1  Presidente Dutra         41         Good             1            Good
# 2  Presidente Dutra         41         Good             1            Good
# 3   Priolo Gargallo         66     Moderate             1            Good
# 4         Przasnysz         34         Good             1            Good
# 5       Punta Gorda         54     Moderate             1            Good
# 6       Punta Gorda         54     Moderate             1            Good
# 7             Puurs         64     Moderate             1            Good
# 8        Pyatigorsk         54     Moderate             1            Good
# 9           Qinzhou         68     Moderate             2            Good
#
#    Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category
# 0               36               Good              0             Good  \
# ...

# %%
data.tail(10)
# Out:
#                    City  AQI Value                    AQI Category
# 16685           Viterbo         55                        Moderate  \
# 16686          Wangqing        101  Unhealthy for Sensitive Groups
# 16687           El Reno         39                            Good
# 16688           Urmston         33                            Good
# 16689          Shaoguan        160                       Unhealthy
# 16690  Highland Springs         54                        Moderate
# 16691            Martin         71                        Moderate
# 16692            Martin         71                        Moderate
# 16693            Sceaux         50                            Good
# 16694       Westerville         71                        Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category
# 16685             1            Good               24               Good  \
# 16686             3            Good               35               Good
# ...

# %%
data.shape
# Out:
# (16695, 13)

# %% [markdown]
# ## Ploting Histogram For the Distribution Of AQI Values

# %%
plt.figure(figsize=(14,7))
sns.distplot(data["AQI Value"])
plt.title("Distribution of AQI Values")
# Out:
# /var/folders/vb/z7xsmz8x3c9bq80x60ktk0mm0000gn/T/ipykernel_15464/1263324256.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["AQI Value"])
# Text(0.5, 1.0, 'Distribution of AQI Values')

# %% [markdown]
# ## Ploting Graph for AQI Category

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=data,x="AQI Category")

plt.title("AQI Category Distribution")
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Moderate'),
#   Text(1, 0, 'Good'),
#   Text(2, 0, 'Unhealthy'),
#   Text(3, 0, 'Very Unhealthy'),
#   Text(4, 0, 'Unhealthy for Sensitive Groups'),
#   Text(5, 0, 'Hazardous')])

# %%
types=data["PM2.5 AQI Category"].value_counts()
types
# Out:
# PM2.5 AQI Category
# Good                              7936
# Moderate                          6882
# Unhealthy for Sensitive Groups     881
# Unhealthy                          828
# Very Unhealthy                     115
# Hazardous                           53
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))
plt.pie(types.values,labels=types.index,autopct="%.2f%%",startangle=-5,)
plt.tight_layout()

# %%
data.columns
# Out:
# Index(['City', 'AQI Value', 'AQI Category', 'CO AQI Value', 'CO AQI Category',
#        'Ozone AQI Value', 'Ozone AQI Category', 'NO2 AQI Value',
#        'NO2 AQI Category', 'PM2.5 AQI Value', 'PM2.5 AQI Category', 'lat',
#        'lng'],
#       dtype='object')

# %% [markdown]
# ## Now Will Define Relationship B/w All Values

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(data=data,x="AQI Value",y="PM2.5 AQI Value")
plt.title("Relationship B/W AQI Values And PM2.5 AQI Value")
# Out:
# Text(0.5, 1.0, 'Relationship B/W AQI Values And PM2.5 AQI Value')

# %% [markdown]
# Relationship B/W CO AQI Value and NO2 AQI Value

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(x="CO AQI Value",y="NO2 AQI Value",data=data)
plt.title("Relationship B/W CO AQI Value and NO2 AQI Value")
# Out:
# Text(0.5, 1.0, 'Relationship B/W CO AQI Value and NO2 AQI Value')

# %% [markdown]
# ## AQI Category vs. AQI Value

# %%
plt.figure(figsize=(14,8))
sns.catplot(x="AQI Category",y="AQI Value",kind="box",data=data)

plt.xticks(rotation=35)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Moderate'),
#   Text(1, 0, 'Good'),
#   Text(2, 0, 'Unhealthy'),
#   Text(3, 0, 'Very Unhealthy'),
#   Text(4, 0, 'Unhealthy for Sensitive Groups'),
#   Text(5, 0, 'Hazardous')])

# %% [markdown]
# ## Geographic distribution of cities

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(x="lng",y="lat",data=data,alpha=0.5)
plt.title("Geographic distribution of cities")
# Out:
# Text(0.5, 1.0, 'Geographic distribution of cities')

# %% [markdown]
# ## Comparison of AQI Categories by Pollutant

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="AQI Category",y="AQI Value",data=data)
plt.title("Comparison of AQI Categories by Pollutant")
plt.xticks(rotation=25)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Moderate'),
#   Text(1, 0, 'Good'),
#   Text(2, 0, 'Unhealthy'),
#   Text(3, 0, 'Very Unhealthy'),
#   Text(4, 0, 'Unhealthy for Sensitive Groups'),
#   Text(5, 0, 'Hazardous')])

# %% [markdown]
# ## Correlation Matrix of Pollutant AQI Values

# %%
#Firstly We Will Findout The Correlation In the Dataset
c=data[['AQI Value','CO AQI Value','Ozone AQI Value','NO2 AQI Value','PM2.5 AQI Value']].corr()
c
# Out:
#                  AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value
# AQI Value         1.000000      0.458523         0.327956       0.308858  \
# CO AQI Value      0.458523      1.000000         0.039752       0.399566
# Ozone AQI Value   0.327956      0.039752         1.000000      -0.251169
# NO2 AQI Value     0.308858      0.399566        -0.251169       1.000000
# PM2.5 AQI Value   0.980360      0.458846         0.233031       0.341455
#
#                  PM2.5 AQI Value
# AQI Value               0.980360
# CO AQI Value            0.458846
# Ozone AQI Value         0.233031
# NO2 AQI Value           0.341455
# PM2.5 AQI Value         1.000000

# %% [markdown]
# ### Now Ploting Graph On Above Values

# %%
plt.figure(figsize=(14,7))
sns.heatmap(c,xticklabels=c.columns,yticklabels=c.columns,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data[['AQI Value','CO AQI Value','Ozone AQI Value','NO2 AQI Value','PM2.5 AQI Value']])

# %%
#Top 10 Cities where AQI values is High
top10=data.nlargest(10,["AQI Value"])
top10
# Out:
#               City  AQI Value AQI Category  CO AQI Value
# 203   Bahawalnagar        500    Hazardous             1  \
# 445      Harunabad        500    Hazardous             1
# 578   Mahendragarh        500    Hazardous             1
# 1623       Phalodi        500    Hazardous             0
# 1808       Jodhpur        500    Hazardous             0
# 3750         Delhi        500    Hazardous             1
# 3751         Delhi        500    Hazardous             1
# 3768       Durango        500    Hazardous           133
# 3769       Durango        500    Hazardous           133
# 3770       Durango        500    Hazardous           133
#
#                      CO AQI Category  Ozone AQI Value Ozone AQI Category
# 203                             Good               38               Good  \
# 445                             Good               43               Good
# 578                             Good               42               Good
# ...

# %%
#Top 10 Cities where CO AQI Value is High
top1=data.nlargest(10,["CO AQI Value"])
top1
# Out:
#            City  AQI Value    AQI Category  CO AQI Value
# 3768    Durango        500       Hazardous           133  \
# 3769    Durango        500       Hazardous           133
# 3770    Durango        500       Hazardous           133
# 9286       Miri        209  Very Unhealthy            67
# 12994  Boksburg        500       Hazardous            49
# 9727   Alberton        205  Very Unhealthy            41
# 14067    Soweto        185       Unhealthy            36
# 10621   Bulungu        372       Hazardous            35
# 6362      Lampa        358       Hazardous            28
# 6363      Lampa        358       Hazardous            28
#
#                       CO AQI Category  Ozone AQI Value Ozone AQI Category
# 3768   Unhealthy for Sensitive Groups                0               Good  \
# 3769   Unhealthy for Sensitive Groups                0               Good
# 3770   Unhealthy for Sensitive Groups                0               Good
# ...

# %%
#Top 10 Cities where Ozone AQI values is High
top2=data.nlargest(10,["Ozone AQI Value"])
top2
# Out:
#             City  AQI Value    AQI Category  CO AQI Value CO AQI Category
# 7953       Karaj        222  Very Unhealthy             5            Good  \
# 13119        Qom        214  Very Unhealthy             4            Good
# 6903       Jinan        210  Very Unhealthy             7            Good
# 9286        Miri        209  Very Unhealthy            67        Moderate
# 10584     Cikupa        207  Very Unhealthy             5            Good
# 15444     Jinsha        207  Very Unhealthy             7            Good
# 624      Nantong        206  Very Unhealthy             7            Good
# 3856     Taizhou        206  Very Unhealthy             5            Good
# 3857     Taizhou        206  Very Unhealthy             5            Good
# 14931  Jingcheng        206  Very Unhealthy             6            Good
#
#        Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category
# 7953               222     Very Unhealthy              7             Good  \
# ...

# %%
#Top 10 Cities where NO2 AQI Values is High
top3=data.nlargest(10,["NO2 AQI Value"])
top3
# Out:
#                City  AQI Value    AQI Category  CO AQI Value
# 960           Seoul        421       Hazardous            27  \
# 2839        Algiers        154       Unhealthy            10
# 8551        Chengdu        386       Hazardous            28
# 8338  Rangkasbitung        225  Very Unhealthy            11
# 3571          Curug        281  Very Unhealthy            15
# 8406      Chongqing        283  Very Unhealthy            19
# 3768        Durango        500       Hazardous           133
# 3769        Durango        500       Hazardous           133
# 3770        Durango        500       Hazardous           133
# 904      Leuwiliang        264  Very Unhealthy            15
#
#                      CO AQI Category  Ozone AQI Value Ozone AQI Category
# 960                             Good                0               Good  \
# 2839                            Good               33               Good
# ...

# %%
#Top 10 Cities where PM2.5 AQI values is High
top4=data.nlargest(10,["PM2.5 AQI Value"])
top4
# Out:
#              City  AQI Value AQI Category  CO AQI Value
# 3768      Durango        500    Hazardous           133  \
# 3769      Durango        500    Hazardous           133
# 3770      Durango        500    Hazardous           133
# 3853        Nohar        500    Hazardous             1
# 5924   Sardulgarh        500    Hazardous             1
# 9220    Jalalabad        500    Hazardous             1
# 10672    Hasanpur        500    Hazardous             1
# 10673    Hasanpur        500    Hazardous             1
# 12994    Boksburg        500    Hazardous            49
# 14738     Pokaran        500    Hazardous             0
#
#                       CO AQI Category  Ozone AQI Value Ozone AQI Category
# 3768   Unhealthy for Sensitive Groups                0               Good  \
# 3769   Unhealthy for Sensitive Groups                0               Good
# 3770   Unhealthy for Sensitive Groups                0               Good
# ...

# %%
# Calculate the average AQI value for each city
data.groupby('City')['AQI Value'].mean().reset_index()
# Out:
#               City  AQI Value
# 0         Aabenraa       45.0
# 1           Aachen       55.0
# 2          Aalborg       46.0
# 3            Aalen       61.0
# 4         Aalsmeer       38.0
# ...            ...        ...
# 14224      Zwickau       32.0
# 14225      Zwiesel       69.0
# 14226  Zwijndrecht       39.0
# 14227       Zwolle       31.0
# 14228   Zyryanovsk       24.0
#
# [14229 rows x 2 columns]
